# %% [markdown]
# # Init Spark

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = ( 
    SparkSession.builder
            .appName('test').master("yarn")
            .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/19 14:27:14 INFO SparkEnv: Registering MapOutputTracker
# 24/03/19 14:27:14 INFO SparkEnv: Registering BlockManagerMaster
# 24/03/19 14:27:14 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 24/03/19 14:27:14 INFO SparkEnv: Registering OutputCommitCoordinator

# %% [markdown]
# .master("local[*]").  Nếu chạy local. Dấu * tượng trưng cho ý spark được phép dùng hết tài nguyên của máy ( CPU/RAM ) để xử lý
#
# .master("yarn"). Nếu chạy trên cluster YARN
#
#
# Có thể thêm config vào. Một số config để connect với s3
#
#   - .config("spark.jars", "aws-sdk-java-2.17.81.jar")
#
#   - .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
#
#   - .config("spark.hadoop.fs.s3a.access.key", "<your_access_key_id>")
#
#   - .config("spark.hadoop.fs.s3a.secret.key", "<your_secret_access_key>")

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cluster-levanduy-m.asia-east1-c.c.tk01-levanduy.internal:38791">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# !pyspark --version and spark-shell --version
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.3.2
#       /_/
#
# Using Scala version 2.12.18, OpenJDK 64-Bit Server VM, 11.0.20.1
# Branch dataproc-branch-3.3.2
# Compiled by user  on 2024-03-05T22:27:36Z
# Revision 8a05f8da2bcd58acfc0b8d97000abb2c4a6b8f59
# Url https://bigdataoss-internal.googlesource.com/third_party/apache/spark
# Type --help for more information.

# %% [markdown]
# # Read File

# %%
data_storage = "gs://course_crawl/2024/03/19/LeVanDuy_First.parquet"

df = spark.read.parquet(data_storage)

# %%
df.printSchema()
# Out:
# root
#  |-- url: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- instructors: string (nullable = true)
#  |-- learns: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- level: string (nullable = true)
#  |-- time: string (nullable = true)

# %%
df.show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+-----------------+--------------------+--------------------+--------------------+------------------+--------------------+
# |                 url|                name|         language|         description|         instructors|              learns|             level|                time|
# +--------------------+--------------------+-----------------+--------------------+--------------------+--------------------+------------------+--------------------+
# |https://www.cours...|Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...|[Understand the i...|    Beginner level|6 months at 7 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|[Learn the skills...|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|[Learn the skills...|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|[Learn the skills...|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|[Learn the skills...|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|[Learn the skills...|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Start your career...|Google Cloud Trai...|[Learn the skills...|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...|[Automate tasks b...|    Beginner level|6 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Developer Best Pr...|Google Cloud Trai...|[Identify the pur...|Intermediate level|2 months at 5 hou...|
# |https://www.cours...|AWS Cloud Solutio...|Taught in English|Start here to bec...|       Morgan Willis|[Make informed de...|Intermediate level|2 months at 10 ho...|
# |https://www.cours...|IBM Applied DevOp...|Taught in English|Advance your care...|        John Rofrano|[Write quality ag...|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Meta AR Developer...|Taught in English|Prepare for a car...|Taught by Meta Staff|[Learn Meta Spark...|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell|[Basic understand...|    Beginner level|6 months at 8 hou...|
# |https://www.cours...|Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton|[Examine the cybe...|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell|[Basic understand...|    Beginner level|5 months at 8 hou...|
# |https://www.cours...|IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...|[Master the full-...|    Beginner level|5 months at 10 ho...|
# |https://www.cours...|IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano|[ Master the most...|    Beginner level|12 months at 10 h...|
# |https://www.cours...|IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|[Master the most ...|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|[Master the most ...|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|[Demonstrate prof...|    Beginner level|6 months at 6 hou...|
# +--------------------+--------------------+-----------------+--------------------+--------------------+--------------------+------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Read Spark with Schema

# %%
from pyspark.sql import types

# %%
schema = types.StructType([
    types.StructField('url', types.StringType(), True),
    types.StructField('name', types.StringType(), True),
    types.StructField('language', types.StringType(), True),
    types.StructField('description', types.StringType(), True),
    types.StructField('instructors', types.StringType(), True),
    types.StructField('learn', types.StringType(), True),
    types.StructField('level', types.StringType(), True),
    types.StructField('time', types.StringType(), True)
])

# %%
df = spark.read \
    .schema(schema) \
    .parquet(data_storage)

# %%
df.show()
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |                 url|                name|         language|         description|         instructors|learn|             level|                time|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |https://www.cours...|Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...| null|    Beginner level|6 months at 7 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Start your career...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...| null|    Beginner level|6 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Developer Best Pr...|Google Cloud Trai...| null|Intermediate level|2 months at 5 hou...|
# |https://www.cours...|AWS Cloud Solutio...|Taught in English|Start here to bec...|       Morgan Willis| null|Intermediate level|2 months at 10 ho...|
# |https://www.cours...|IBM Applied DevOp...|Taught in English|Advance your care...|        John Rofrano| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Meta AR Developer...|Taught in English|Prepare for a car...|Taught by Meta Staff| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell| null|    Beginner level|6 months at 8 hou...|
# |https://www.cours...|Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell| null|    Beginner level|5 months at 8 hou...|
# |https://www.cours...|IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...| null|    Beginner level|5 months at 10 ho...|
# |https://www.cours...|IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano| null|    Beginner level|12 months at 10 h...|
# |https://www.cours...|IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff| null|    Beginner level|6 months at 6 hou...|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Làm việc với cột ( columns )

# %%
df = df.withColumnRenamed("url", "url_course")

# %%
df.show()
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |          url_course|                name|         language|         description|         instructors|learn|             level|                time|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |https://www.cours...|Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...| null|    Beginner level|6 months at 7 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Start your career...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...| null|    Beginner level|6 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Developer Best Pr...|Google Cloud Trai...| null|Intermediate level|2 months at 5 hou...|
# |https://www.cours...|AWS Cloud Solutio...|Taught in English|Start here to bec...|       Morgan Willis| null|Intermediate level|2 months at 10 ho...|
# |https://www.cours...|IBM Applied DevOp...|Taught in English|Advance your care...|        John Rofrano| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Meta AR Developer...|Taught in English|Prepare for a car...|Taught by Meta Staff| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell| null|    Beginner level|6 months at 8 hou...|
# |https://www.cours...|Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell| null|    Beginner level|5 months at 8 hou...|
# |https://www.cours...|IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...| null|    Beginner level|5 months at 10 ho...|
# |https://www.cours...|IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano| null|    Beginner level|12 months at 10 h...|
# |https://www.cours...|IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff| null|    Beginner level|6 months at 6 hou...|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# only showing top 20 rows

# %%
df.select("language","level").describe().show()
# Out:
# +-------+-----------------+------------------+
# |summary|         language|             level|
# +-------+-----------------+------------------+
# |  count|               34|                34|
# |   mean|             null|              null|
# | stddev|             null|              null|
# |    min|Taught in English|    Beginner level|
# |    max|Taught in English|Intermediate level|
# +-------+-----------------+------------------+

# %%
df.printSchema()
# Out:
# root
#  |-- url_course: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- instructors: string (nullable = true)
#  |-- learn: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- time: string (nullable = true)

# %% [markdown]
# # Pyspark và SQL

# %% [markdown]
# ### SELECT

# %%
df.select("*").show()
# Out:
# [Stage 7:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |          url_course|                name|         language|         description|         instructors|learn|             level|                time|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |https://www.cours...|Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...| null|    Beginner level|6 months at 7 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Start your career...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...| null|    Beginner level|6 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Developer Best Pr...|Google Cloud Trai...| null|Intermediate level|2 months at 5 hou...|
# |https://www.cours...|AWS Cloud Solutio...|Taught in English|Start here to bec...|       Morgan Willis| null|Intermediate level|2 months at 10 ho...|
# |https://www.cours...|IBM Applied DevOp...|Taught in English|Advance your care...|        John Rofrano| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Meta AR Developer...|Taught in English|Prepare for a car...|Taught by Meta Staff| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell| null|    Beginner level|6 months at 8 hou...|
# |https://www.cours...|Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell| null|    Beginner level|5 months at 8 hou...|
# |https://www.cours...|IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...| null|    Beginner level|5 months at 10 ho...|
# |https://www.cours...|IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano| null|    Beginner level|12 months at 10 h...|
# |https://www.cours...|IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff| null|    Beginner level|6 months at 6 hou...|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# only showing top 20 rows

# %%
df.select("*").head()
# Out:
# Row(url_course='https://www.coursera.org/professional-certificates/google-cybersecurity', name='Google Cybersecurity Professional Certificate', language='Taught in English', description='This is your path to a career in cybersecurity. In this certificate program, you’ll learn in-demand skills that can have you job-ready in less than 6 months. No degree or experience required. ', instructors='Google Career Certificates', learn=None, level='Beginner level', time='6 months at 7 hours a week')

# %%
df.select(
    "name",
    "language",
    "description",
    "instructors",
    "level",
    "time").show()
# Out:
# [Stage 9:>                                                          (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+------------------+--------------------+
# |                name|         language|         description|         instructors|             level|                time|
# +--------------------+-----------------+--------------------+--------------------+------------------+--------------------+
# |Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...|    Beginner level|6 months at 7 hou...|
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|Intermediate level|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|Intermediate level|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|Intermediate level|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|    Beginner level|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|Intermediate level|3 months at 10 ho...|
# |Preparing for Goo...|Taught in English|Start your career...|Google Cloud Trai...|Intermediate level|1 month at 10 hou...|
# |Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...|    Beginner level|6 months at 10 ho...|
# |Preparing for Goo...|Taught in English|Developer Best Pr...|Google Cloud Trai...|Intermediate level|2 months at 5 hou...|
# |AWS Cloud Solutio...|Taught in English|Start here to bec...|       Morgan Willis|Intermediate level|2 months at 10 ho...|
# |IBM Applied DevOp...|Taught in English|Advance your care...|        John Rofrano|Intermediate level|3 months at 10 ho...|
# |Meta AR Developer...|Taught in English|Prepare for a car...|Taught by Meta Staff|Intermediate level|3 months at 10 ho...|
# |Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell|    Beginner level|6 months at 8 hou...|
# |Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton|    Beginner level|1 month at 10 hou...|
# |Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell|    Beginner level|5 months at 8 hou...|
# |IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...|    Beginner level|5 months at 10 ho...|
# |IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano|    Beginner level|12 months at 10 h...|
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|    Beginner level|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|    Beginner level|3 months at 10 ho...|
# |Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|    Beginner level|6 months at 6 hou...|
# +--------------------+-----------------+--------------------+--------------------+------------------+--------------------+
# only showing top 20 rows

# %%
df.select("instructors").distinct().show()
# Out:
# [Stage 10:>                                                         (0 + 1) / 1]
# +--------------------+
# |         instructors|
# +--------------------+
# |Taught by Meta Staff|
# |     Leslie Reynolds|
# |IBM Skills Networ...|
# |Google Cloud Trai...|
# |           Microsoft|
# |       Morgan Willis|
# |      Shadow Farrell|
# |        John Rofrano|
# |Google Career Cer...|
# |        James Dalton|
# +--------------------+

# %%
from pyspark.sql import functions as F

# %%
df.select(
    F.col("instructors"),
    F.col("level"),
).distinct().show()
# Out:
# [Stage 13:>                                                         (0 + 1) / 1]
# +--------------------+------------------+
# |         instructors|             level|
# +--------------------+------------------+
# |           Microsoft|    Beginner level|
# |     Leslie Reynolds|    Beginner level|
# |Taught by Meta Staff|Intermediate level|
# |       Morgan Willis|Intermediate level|
# |      Shadow Farrell|    Beginner level|
# |       Morgan Willis|    Beginner level|
# |        John Rofrano|    Beginner level|
# |Taught by Meta Staff|    Beginner level|
# |Google Cloud Trai...|Intermediate level|
# |Google Career Cer...|    Beginner level|
# |        James Dalton|    Beginner level|
# |        John Rofrano|Intermediate level|
# |Google Cloud Trai...|    Beginner level|
# |IBM Skills Networ...|    Beginner level|
# +--------------------+------------------+

# %% [markdown]
# ### WHERE

# %%
df.select(
    F.col("name"),
    F.col("language"),
    F.col("description"),
    F.col("instructors"),
    F.col("level"),
    F.col("time")
).filter(F.col("instructors").contains("Taught by Meta Staff")).show()
# Out:
# [Stage 16:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+------------------+--------------------+
# |                name|         language|         description|         instructors|             level|                time|
# +--------------------+-----------------+--------------------+--------------------+------------------+--------------------+
# |Meta AR Developer...|Taught in English|Prepare for a car...|Taught by Meta Staff|Intermediate level|3 months at 10 ho...|
# |Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|    Beginner level|6 months at 6 hou...|
# |Meta iOS Develope...|Taught in English|Launch your caree...|Taught by Meta Staff|    Beginner level|8 months at 7 hou...|
# |Meta Android Deve...|Taught in English|Launch your caree...|Taught by Meta Staff|    Beginner level|8 months at 7 hou...|
# |Meta Back-End Dev...|Taught in English|Launch your caree...|Taught by Meta Staff|    Beginner level|8 months at 6 hou...|
# |Meta Front-End De...|Taught in English|Launch your caree...|Taught by Meta Staff|    Beginner level|7 months at 6 hou...|
# +--------------------+-----------------+--------------------+--------------------+------------------+--------------------+

# %%
df.select(
    F.col("name"),
    F.col("language"),
    F.col("description"),
    F.col("instructors"),
    F.col("level"),
    F.col("time")
).filter(F.col("level").contains("Beginner level")).show()
# Out:
# [Stage 17:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |                name|         language|         description|         instructors|         level|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 7 hou...|
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|Beginner level|1 month at 10 hou...|
# |Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell|Beginner level|6 months at 8 hou...|
# |Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton|Beginner level|1 month at 10 hou...|
# |Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell|Beginner level|5 months at 8 hou...|
# |IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...|Beginner level|5 months at 10 ho...|
# |IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano|Beginner level|12 months at 10 h...|
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|6 months at 6 hou...|
# |IBM IT Project Ma...|Taught in English|Prepare for caree...|        John Rofrano|Beginner level|4 months at 10 ho...|
# | IBM and ISC2 Cyb...|Taught in English|Launch your caree...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |Meta iOS Develope...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 7 hou...|
# |Meta Android Deve...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 7 hou...|
# |AWS Cloud Technol...|Taught in English|Start a career as...|       Morgan Willis|Beginner level|4 months at 10 ho...|
# |SAP Technology Co...|Taught in English|Unlock your poten...|     Leslie Reynolds|Beginner level|7 months at 3 hou...|
# |IBM DevOps and So...|Taught in English|Launch your DevOp...|        John Rofrano|Beginner level|3 months at 10 ho...|
# |Meta Back-End Dev...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 6 hou...|
# |Microsoft Cyberse...|Taught in English|Launch your caree...|           Microsoft|Beginner level|6 months at 10 ho...|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# only showing top 20 rows

# %%
condition = (F.col("time").contains("3 months at 10 hours a week")) & (F.col("level").contains("Beginner level"))

df.select(
    F.col("name"),
    F.col("language"),
    F.col("description"),
    F.col("instructors"),
    F.col("level"),
    F.col("time")
).filter(condition).show()
# Out:
# [Stage 18:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |                name|         language|         description|         instructors|         level|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# | IBM and ISC2 Cyb...|Taught in English|Launch your caree...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM DevOps and So...|Taught in English|Launch your DevOp...|        John Rofrano|Beginner level|3 months at 10 ho...|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+

# %% [markdown]
# ### ORDER BY

# %%
df.select(
    F.col("name"),
    F.col("language"),
    F.col("description"),
    F.col("instructors"),
    F.col("level"),
    F.col("time")
).filter(F.col("level").contains("Beginner level")).orderBy("name").show()
# Out:
# [Stage 19:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |                name|         language|         description|         instructors|         level|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# | IBM and ISC2 Cyb...|Taught in English|Launch your caree...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |AWS Cloud Technol...|Taught in English|Start a career as...|       Morgan Willis|Beginner level|4 months at 10 ho...|
# |Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell|Beginner level|6 months at 8 hou...|
# |Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell|Beginner level|5 months at 8 hou...|
# |Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 7 hou...|
# |Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Google IT Support...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Google UX Design ...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano|Beginner level|12 months at 10 h...|
# |IBM Cybersecurity...|Taught in English|Get ready to laun...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM DevOps and So...|Taught in English|Launch your DevOp...|        John Rofrano|Beginner level|3 months at 10 ho...|
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM Full Stack So...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...|Beginner level|5 months at 10 ho...|
# |IBM IT Project Ma...|Taught in English|Prepare for caree...|        John Rofrano|Beginner level|4 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |Meta Android Deve...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 7 hou...|
# |Meta Back-End Dev...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 6 hou...|
# |Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|6 months at 6 hou...|
# |Meta Front-End De...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|7 months at 6 hou...|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# only showing top 20 rows

# %%
df.select(
    F.col("name"),
    F.col("language"),
    F.col("description"),
    F.col("instructors"),
    F.col("level"),
    F.col("time")
).filter(F.col("level").contains("Beginner level")).sort("time").show()
# Out:
# [Stage 20:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |                name|         language|         description|         instructors|         level|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|Beginner level|1 month at 10 hou...|
# |Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton|Beginner level|1 month at 10 hou...|
# |IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano|Beginner level|12 months at 10 h...|
# | IBM and ISC2 Cyb...|Taught in English|Launch your caree...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM DevOps and So...|Taught in English|Launch your DevOp...|        John Rofrano|Beginner level|3 months at 10 ho...|
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM IT Project Ma...|Taught in English|Prepare for caree...|        John Rofrano|Beginner level|4 months at 10 ho...|
# |AWS Cloud Technol...|Taught in English|Start a career as...|       Morgan Willis|Beginner level|4 months at 10 ho...|
# |IBM Cybersecurity...|Taught in English|Get ready to laun...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM Full Stack So...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...|Beginner level|5 months at 10 ho...|
# |Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell|Beginner level|5 months at 8 hou...|
# |Microsoft Cyberse...|Taught in English|Launch your caree...|           Microsoft|Beginner level|6 months at 10 ho...|
# |Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Google UX Design ...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Google IT Support...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|6 months at 6 hou...|
# |Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 7 hou...|
# |Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell|Beginner level|6 months at 8 hou...|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# only showing top 20 rows

# %%
df.select(
    F.col("name"),
    F.col("language"),
    F.col("description"),
    F.col("instructors"),
    F.col("level"),
    F.col("time")
).filter(F.col("level").contains("Beginner level")).sort(F.col("time").desc()).show()
# Out:
# [Stage 21:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |                name|         language|         description|         instructors|         level|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |Meta iOS Develope...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 7 hou...|
# |Meta Android Deve...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 7 hou...|
# |Meta Back-End Dev...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 6 hou...|
# |Meta Front-End De...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|7 months at 6 hou...|
# |SAP Technology Co...|Taught in English|Unlock your poten...|     Leslie Reynolds|Beginner level|7 months at 3 hou...|
# |Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell|Beginner level|6 months at 8 hou...|
# |Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 7 hou...|
# |Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|6 months at 6 hou...|
# |Google IT Support...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Microsoft Cyberse...|Taught in English|Launch your caree...|           Microsoft|Beginner level|6 months at 10 ho...|
# |Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Google UX Design ...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell|Beginner level|5 months at 8 hou...|
# |IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...|Beginner level|5 months at 10 ho...|
# |AWS Cloud Technol...|Taught in English|Start a career as...|       Morgan Willis|Beginner level|4 months at 10 ho...|
# |IBM Full Stack So...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM IT Project Ma...|Taught in English|Prepare for caree...|        John Rofrano|Beginner level|4 months at 10 ho...|
# |IBM Cybersecurity...|Taught in English|Get ready to laun...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# only showing top 20 rows

# %%
(
    df.select(
        F.col("name"),
        F.col("language"),
        F.col("description"),
        F.col("instructors"),
        F.col("level"),
        F.col("time")
    )
    .filter(F.col("level").contains("Beginner level"))
    .sort(F.desc("time"))
    .show()
)
# Out:
# [Stage 22:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |                name|         language|         description|         instructors|         level|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |Meta iOS Develope...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 7 hou...|
# |Meta Android Deve...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 7 hou...|
# |Meta Back-End Dev...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|8 months at 6 hou...|
# |Meta Front-End De...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|7 months at 6 hou...|
# |SAP Technology Co...|Taught in English|Unlock your poten...|     Leslie Reynolds|Beginner level|7 months at 3 hou...|
# |Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell|Beginner level|6 months at 8 hou...|
# |Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 7 hou...|
# |Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff|Beginner level|6 months at 6 hou...|
# |Google IT Support...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Microsoft Cyberse...|Taught in English|Launch your caree...|           Microsoft|Beginner level|6 months at 10 ho...|
# |Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Google UX Design ...|Taught in English|This is your path...|Google Career Cer...|Beginner level|6 months at 10 ho...|
# |Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell|Beginner level|5 months at 8 hou...|
# |IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...|Beginner level|5 months at 10 ho...|
# |AWS Cloud Technol...|Taught in English|Start a career as...|       Morgan Willis|Beginner level|4 months at 10 ho...|
# |IBM Full Stack So...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM IT Project Ma...|Taught in English|Prepare for caree...|        John Rofrano|Beginner level|4 months at 10 ho...|
# |IBM Cybersecurity...|Taught in English|Get ready to laun...|IBM Skills Networ...|Beginner level|4 months at 10 ho...|
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ###  Limit

# %%
(
    df.select(
        F.col("name"),
        F.col("language"),
        F.col("description"),
        F.col("instructors"),
        F.col("level"),
        F.col("time")
    )
    .filter(F.col("level").contains("Beginner level"))
    .sort(F.col("time"))
    .limit(5)
    .show()
)
# Out:
# [Stage 23:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |                name|         language|         description|         instructors|         level|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+
# |Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...|Beginner level|1 month at 10 hou...|
# |Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton|Beginner level|1 month at 10 hou...|
# |IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano|Beginner level|12 months at 10 h...|
# |IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# |IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...|Beginner level|3 months at 10 ho...|
# +--------------------+-----------------+--------------------+--------------------+--------------+--------------------+

# %% [markdown]
# ### GROUP BY

# %%
 (
    df.select(
        F.col("instructors"),
        F.col("time")
    )
     .groupBy("instructors")
     .count()
     .show()
 )
# Out:
# [Stage 24:>                                                         (0 + 1) / 1]
# +--------------------+-----+
# |         instructors|count|
# +--------------------+-----+
# |Taught by Meta Staff|    6|
# |     Leslie Reynolds|    1|
# |IBM Skills Networ...|    6|
# |Google Cloud Trai...|    7|
# |           Microsoft|    1|
# |       Morgan Willis|    2|
# |      Shadow Farrell|    2|
# |        John Rofrano|    4|
# |Google Career Cer...|    4|
# |        James Dalton|    1|
# +--------------------+-----+

# %% [markdown]
# # User Define Function ( UDF )

# %%
def convert_case(string):
    return string.upper()

convert_case_udf = F.udf(convert_case, returnType=types.StringType())

# %%
( 
    df
    .withColumn('instructors_uppercase', convert_case_udf(F.col("instructors")))
    .select('instructors_uppercase','instructors') 
    .show()
)
# Out:
# [Stage 27:>                                                         (0 + 1) / 1]
# +---------------------+--------------------+
# |instructors_uppercase|         instructors|
# +---------------------+--------------------+
# | GOOGLE CAREER CER...|Google Career Cer...|
# | GOOGLE CLOUD TRAI...|Google Cloud Trai...|
# | GOOGLE CLOUD TRAI...|Google Cloud Trai...|
# | GOOGLE CLOUD TRAI...|Google Cloud Trai...|
# | GOOGLE CLOUD TRAI...|Google Cloud Trai...|
# | GOOGLE CLOUD TRAI...|Google Cloud Trai...|
# | GOOGLE CLOUD TRAI...|Google Cloud Trai...|
# | GOOGLE CAREER CER...|Google Career Cer...|
# | GOOGLE CLOUD TRAI...|Google Cloud Trai...|
# |        MORGAN WILLIS|       Morgan Willis|
# |         JOHN ROFRANO|        John Rofrano|
# | TAUGHT BY META STAFF|Taught by Meta Staff|
# |       SHADOW FARRELL|      Shadow Farrell|
# |         JAMES DALTON|        James Dalton|
# |       SHADOW FARRELL|      Shadow Farrell|
# | IBM SKILLS NETWOR...|IBM Skills Networ...|
# |         JOHN ROFRANO|        John Rofrano|
# | IBM SKILLS NETWOR...|IBM Skills Networ...|
# | IBM SKILLS NETWOR...|IBM Skills Networ...|
# | TAUGHT BY META STAFF|Taught by Meta Staff|
# +---------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Spark SQL

# %%
df.createOrReplaceTempView("df")
# df.registerTempTable("df")

# %%
spark.sql(" SELECT * from df ").show()
# Out:
# [Stage 28:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |          url_course|                name|         language|         description|         instructors|learn|             level|                time|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# |https://www.cours...|Google Cybersecur...|Taught in English|This is your path...|Google Career Cer...| null|    Beginner level|6 months at 7 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Advance your care...|Google Cloud Trai...| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Start your career...|Google Cloud Trai...| null|Intermediate level|1 month at 10 hou...|
# |https://www.cours...|Google IT Automat...|Taught in English|Learn in-demand s...|Google Career Cer...| null|    Beginner level|6 months at 10 ho...|
# |https://www.cours...|Preparing for Goo...|Taught in English|Developer Best Pr...|Google Cloud Trai...| null|Intermediate level|2 months at 5 hou...|
# |https://www.cours...|AWS Cloud Solutio...|Taught in English|Start here to bec...|       Morgan Willis| null|Intermediate level|2 months at 10 ho...|
# |https://www.cours...|IBM Applied DevOp...|Taught in English|Advance your care...|        John Rofrano| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Meta AR Developer...|Taught in English|Prepare for a car...|Taught by Meta Staff| null|Intermediate level|3 months at 10 ho...|
# |https://www.cours...|Akamai Customer C...|Taught in English|Start Your Career...|      Shadow Farrell| null|    Beginner level|6 months at 8 hou...|
# |https://www.cours...|Palo Alto Network...|Taught in English|Palo Alto Network...|        James Dalton| null|    Beginner level|1 month at 10 hou...|
# |https://www.cours...|Akamai Network En...|Taught in English|Launch Your Caree...|      Shadow Farrell| null|    Beginner level|5 months at 8 hou...|
# |https://www.cours...|IBM Full-Stack Ja...|Taught in English|Launch your Full-...|IBM Skills Networ...| null|    Beginner level|5 months at 10 ho...|
# |https://www.cours...|IBM Back-End Deve...|Taught in English|Prepare for a car...|        John Rofrano| null|    Beginner level|12 months at 10 h...|
# |https://www.cours...|IBM Front-End Dev...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|IBM IT Support  P...|Taught in English|Prepare for a car...|IBM Skills Networ...| null|    Beginner level|3 months at 10 ho...|
# |https://www.cours...|Meta Database Eng...|Taught in English|Launch your caree...|Taught by Meta Staff| null|    Beginner level|6 months at 6 hou...|
# +--------------------+--------------------+-----------------+--------------------+--------------------+-----+------------------+--------------------+
# only showing top 20 rows

# %%
query = """
SELECT name, language, instructors, description, time
FROM df WHERE level == 'Beginner level'

""" 
spark.sql(query).show()
# Out:
# [Stage 29:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# |                name|         language|         instructors|         description|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# |Google Cybersecur...|Taught in English|Google Career Cer...|This is your path...|6 months at 7 hou...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Advance your care...|1 month at 10 hou...|
# |Google IT Automat...|Taught in English|Google Career Cer...|Learn in-demand s...|6 months at 10 ho...|
# |Akamai Customer C...|Taught in English|      Shadow Farrell|Start Your Career...|6 months at 8 hou...|
# |Palo Alto Network...|Taught in English|        James Dalton|Palo Alto Network...|1 month at 10 hou...|
# |Akamai Network En...|Taught in English|      Shadow Farrell|Launch Your Caree...|5 months at 8 hou...|
# |IBM Full-Stack Ja...|Taught in English|IBM Skills Networ...|Launch your Full-...|5 months at 10 ho...|
# |IBM Back-End Deve...|Taught in English|        John Rofrano|Prepare for a car...|12 months at 10 h...|
# |IBM Front-End Dev...|Taught in English|IBM Skills Networ...|Prepare for a car...|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|IBM Skills Networ...|Prepare for a car...|3 months at 10 ho...|
# |Meta Database Eng...|Taught in English|Taught by Meta Staff|Launch your caree...|6 months at 6 hou...|
# |IBM IT Project Ma...|Taught in English|        John Rofrano|Prepare for caree...|4 months at 10 ho...|
# | IBM and ISC2 Cyb...|Taught in English|IBM Skills Networ...|Launch your caree...|3 months at 10 ho...|
# |Meta iOS Develope...|Taught in English|Taught by Meta Staff|Launch your caree...|8 months at 7 hou...|
# |Meta Android Deve...|Taught in English|Taught by Meta Staff|Launch your caree...|8 months at 7 hou...|
# |AWS Cloud Technol...|Taught in English|       Morgan Willis|Start a career as...|4 months at 10 ho...|
# |SAP Technology Co...|Taught in English|     Leslie Reynolds|Unlock your poten...|7 months at 3 hou...|
# |IBM DevOps and So...|Taught in English|        John Rofrano|Launch your DevOp...|3 months at 10 ho...|
# |Meta Back-End Dev...|Taught in English|Taught by Meta Staff|Launch your caree...|8 months at 6 hou...|
# |Microsoft Cyberse...|Taught in English|           Microsoft|Launch your caree...|6 months at 10 ho...|
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Ghi kết quả ra file parquet

# %%
query = """

SELECT name, language, instructors, description, time
FROM df WHERE level == 'Beginner level'

""" 

spark.sql(query).write.parquet("gs://course_crawl/2024/03/19/LeVanDuy_Last.parquet",
                               mode = "overwrite")

#Dùng  write.partitionBy(col).parquet để partition

# %%
result_df = spark.read.parquet("gs://course_crawl/2024/03/19/LeVanDuy_Last.parquet")

# %%
result_df.show()
# Out:
# [Stage 33:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# |                name|         language|         instructors|         description|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# |Google Cybersecur...|Taught in English|Google Career Cer...|This is your path...|6 months at 7 hou...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Advance your care...|1 month at 10 hou...|
# |Google IT Automat...|Taught in English|Google Career Cer...|Learn in-demand s...|6 months at 10 ho...|
# |Akamai Customer C...|Taught in English|      Shadow Farrell|Start Your Career...|6 months at 8 hou...|
# |Palo Alto Network...|Taught in English|        James Dalton|Palo Alto Network...|1 month at 10 hou...|
# |Akamai Network En...|Taught in English|      Shadow Farrell|Launch Your Caree...|5 months at 8 hou...|
# |IBM Full-Stack Ja...|Taught in English|IBM Skills Networ...|Launch your Full-...|5 months at 10 ho...|
# |IBM Back-End Deve...|Taught in English|        John Rofrano|Prepare for a car...|12 months at 10 h...|
# |IBM Front-End Dev...|Taught in English|IBM Skills Networ...|Prepare for a car...|3 months at 10 ho...|
# |IBM IT Support  P...|Taught in English|IBM Skills Networ...|Prepare for a car...|3 months at 10 ho...|
# |Meta Database Eng...|Taught in English|Taught by Meta Staff|Launch your caree...|6 months at 6 hou...|
# |IBM IT Project Ma...|Taught in English|        John Rofrano|Prepare for caree...|4 months at 10 ho...|
# | IBM and ISC2 Cyb...|Taught in English|IBM Skills Networ...|Launch your caree...|3 months at 10 ho...|
# |Meta iOS Develope...|Taught in English|Taught by Meta Staff|Launch your caree...|8 months at 7 hou...|
# |Meta Android Deve...|Taught in English|Taught by Meta Staff|Launch your caree...|8 months at 7 hou...|
# |AWS Cloud Technol...|Taught in English|       Morgan Willis|Start a career as...|4 months at 10 ho...|
# |SAP Technology Co...|Taught in English|     Leslie Reynolds|Unlock your poten...|7 months at 3 hou...|
# |IBM DevOps and So...|Taught in English|        John Rofrano|Launch your DevOp...|3 months at 10 ho...|
# |Meta Back-End Dev...|Taught in English|Taught by Meta Staff|Launch your caree...|8 months at 6 hou...|
# |Microsoft Cyberse...|Taught in English|           Microsoft|Launch your caree...|6 months at 10 ho...|
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Ví dụ thực tế.

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types

spark = ( 
    SparkSession.builder
            .master("yarn") 
            .appName('Google Courses')
            .getOrCreate()
)

schema = types.StructType([
    types.StructField('url', types.StringType(), True),
    types.StructField('name', types.StringType(), True),
    types.StructField('language', types.StringType(), True),
    types.StructField('description', types.StringType(), True),
    types.StructField('instructors', types.StringType(), True),
    types.StructField('learn', types.StringType(), True),
    types.StructField('level', types.StringType(), True),
    types.StructField('time', types.StringType(), True)
])

data_storage = "gs://course_crawl/2024/03/19/LeVanDuy_First.parquet"
data_write = "gs://course_crawl/2024/03/19/google_courses"

df = spark.read.parquet(data_storage)

df.createOrReplaceTempView("df")
query = """

SELECT name, language, instructors, description, time
FROM df WHERE instructors == 'Google Cloud Training'

""" 

spark.sql(query).write.parquet(data_write,
                        mode = "overwrite")
# Out:
# 24/03/19 14:40:02 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
result_df = spark.read.parquet("gs://course_crawl/2024/03/19/google_courses")

# %%
result_df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- instructors: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- time: string (nullable = true)

# %%
result_df.show()
# Out:
# [Stage 37:>                                                         (0 + 1) / 1]
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# |                name|         language|         instructors|         description|                time|
# +--------------------+-----------------+--------------------+--------------------+--------------------+
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Advance your care...|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Advance your care...|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Advance your care...|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Advance your care...|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Advance your care...|3 months at 10 ho...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Start your career...|1 month at 10 hou...|
# |Preparing for Goo...|Taught in English|Google Cloud Trai...|Developer Best Pr...|2 months at 5 hou...|
# +--------------------+-----------------+--------------------+--------------------+--------------------+

# %% [markdown]
# # RDD

# %%
df.select( 
    F.col('name'),
    F.col('instructors')
).limit(10).show()
# Out:
# [Stage 39:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+
# |                name|         instructors|
# +--------------------+--------------------+
# |Google Cybersecur...|Google Career Cer...|
# |Preparing for Goo...|Google Cloud Trai...|
# |Preparing for Goo...|Google Cloud Trai...|
# |Preparing for Goo...|Google Cloud Trai...|
# |Preparing for Goo...|Google Cloud Trai...|
# |Preparing for Goo...|Google Cloud Trai...|
# |Preparing for Goo...|Google Cloud Trai...|
# |Google IT Automat...|Google Career Cer...|
# |Preparing for Goo...|Google Cloud Trai...|
# |AWS Cloud Solutio...|       Morgan Willis|
# +--------------------+--------------------+

# %%
rdd_course_body = df.select("name","instructors").rdd

# %%
rdd_course_body
# Out:
# MapPartitionsRDD[149] at javaToPython at NativeMethodAccessorImpl.java:0

# %%
rdd_course_body.take(1)
# Out:
# [Row(name='Google Cybersecurity Professional Certificate', instructors='Google Career Certificates')]

# %%
all_data = rdd_course_body.collect()

# %%
rdd_course_body.getNumPartitions()
# Out:
# 1

# %%
rdd_course_body.repartition(4).getNumPartitions()
# Out:
# 4

# %%
rdd_course_body.getNumPartitions()
# Out:
# 1

# %% [markdown]
# ### Map

# %%
def count_len(row):
    name = row.name
    instructors = row.instructors
    return (name, instructors)
        
rdd_course_body.map(count_len).take(10)
# Out:
# [('Google Cybersecurity Professional Certificate',
#   'Google Career Certificates'),
#  ('Preparing for Google Cloud Certification: Cloud Architect Professional Certificate',
#   'Google Cloud Training'),
#  ('Preparing for Google Cloud Certification: Cloud Security Engineer Professional Certificate',
#   'Google Cloud Training'),
#  ('Preparing for Google Cloud Certification: Cloud Network Engineer Professional Certificate',
#   'Google Cloud Training'),
#  ('Preparing for Google Cloud Certification: Cloud DevOps Engineer Professional Certificate',
#   'Google Cloud Training'),
#  ('Preparing for Google Cloud Certification: Machine Learning Engineer Professional Certificate',
#   'Google Cloud Training'),
#  ('Preparing for Google Cloud Certification: Cloud Engineer Professional Certificate',
#   'Google Cloud Training'),
#  ('Google IT Automation with Python Professional Certificate',
#   'Google Career Certificates'),
#  ('Preparing for Google Cloud Certification: Cloud Developer Professional Certificate',
#   'Google Cloud Training'),
#  ('AWS Cloud Solutions Architect  Professional Certificate', 'Morgan Willis')]

# %%
def count_word(row):
    name = row.name
    for word in name.split(" "):
        yield (word,1)
        
rdd_course_body.flatMap(count_word).take(10)
# Out:
# [('Google', 1),
#  ('Cybersecurity', 1),
#  ('Professional', 1),
#  ('Certificate', 1),
#  ('Preparing', 1),
#  ('for', 1),
#  ('Google', 1),
#  ('Cloud', 1),
#  ('Certification:', 1),
#  ('Cloud', 1)]

# %%
def filter_product(row):
    instructors = row.instructors
    return instructors != "Google Cloud Training"
        
( 
    rdd_course_body
        .filter(filter_product)
        .map(count_len)
        .take(10)
)
# Out:
# [('Google Cybersecurity Professional Certificate',
#   'Google Career Certificates'),
#  ('Google IT Automation with Python Professional Certificate',
#   'Google Career Certificates'),
#  ('AWS Cloud Solutions Architect  Professional Certificate', 'Morgan Willis'),
#  ('IBM Applied DevOps Engineering Professional Certificate', 'John Rofrano'),
#  ('Meta AR Developer  Professional Certificate', 'Taught by Meta Staff'),
#  ('Akamai Customer Consulting and Support Professional Certificate',
#   'Shadow Farrell'),
#  ('Palo Alto Networks Cybersecurity Professional Certificate', 'James Dalton'),
#  ('Akamai Network Engineering Professional Certificate', 'Shadow Farrell'),
#  ('IBM Full-Stack JavaScript Developer Professional Certificate',
#   'IBM Skills Network Team'),
#  ('IBM Back-End Development Professional Certificate', 'John Rofrano')]

# %%
def sort_by_value(record):
    return record[1]

(
    rdd_course_body
        .filter(filter_product)
        .map(count_len)
        .sortBy(sort_by_value,ascending = False)
        .take(10)
)
# Out:
# [('Meta AR Developer  Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Database Engineer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta iOS Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Android Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Back-End Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Front-End Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Akamai Customer Consulting and Support Professional Certificate',
#   'Shadow Farrell'),
#  ('Akamai Network Engineering Professional Certificate', 'Shadow Farrell'),
#  ('AWS Cloud Solutions Architect  Professional Certificate', 'Morgan Willis'),
#  ('AWS Cloud Technology Consultant Professional Certificate', 'Morgan Willis')]

# %% [markdown]
# ### Reduce

# %%
def my_sum(x,y):
    return x + y

# %%
(
    rdd_course_body
        .map(count_len)
        .reduceByKey(my_sum)
        .sortBy(sort_by_value,ascending = False)
        .take(10)
)
# Out:
# [('Meta AR Developer  Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Database Engineer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta iOS Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Android Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Back-End Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Meta Front-End Developer Professional Certificate', 'Taught by Meta Staff'),
#  ('Akamai Customer Consulting and Support Professional Certificate',
#   'Shadow Farrell'),
#  ('Akamai Network Engineering Professional Certificate', 'Shadow Farrell'),
#  ('AWS Cloud Solutions Architect  Professional Certificate', 'Morgan Willis'),
#  ('AWS Cloud Technology Consultant Professional Certificate', 'Morgan Willis')]

# %% [markdown]
# # World Count  bằng rdd

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import types

def count_word(row):
    name_count = row.name
    for word in name_count.split(" "):
        yield (word,1)

def my_sum(x,y):
    return x + y

spark = ( 
    SparkSession.builder
            .master("yarn") 
            .appName('Word Count')
            .getOrCreate()
)

schema = types.StructType([
    types.StructField('url', types.StringType(), True),
    types.StructField('name', types.StringType(), True),
    types.StructField('language', types.StringType(), True),
    types.StructField('description', types.StringType(), True),
    types.StructField('instructors', types.StringType(), True),
    types.StructField('learn', types.StringType(), True),
    types.StructField('level', types.StringType(), True),
    types.StructField('time', types.StringType(), True)
])

data_storage = "gs://course_crawl/2024/03/19/LeVanDuy_First.parquet"
data_write = "gs://course_crawl/2024/03/19/word_count"

df = spark.read.schema(schema).parquet(data_storage)
rdd_course_body = df.select("name").rdd
(
    rdd_course_body
        .flatMap(count_word)
        .reduceByKey(my_sum)
        .saveAsTextFile(data_write)
)
# Out:
# 24/03/19 14:33:39 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
from google.cloud import storage

def download_blob(bucket_name, source_blob_name):
    """Downloads a blob from the bucket."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(source_blob_name)
    print(blob.download_as_text())

bucket_name = "course_crawl"
source_blob_name = "2024/03/19/word_count/part-00000"
download_blob(bucket_name, source_blob_name)
# Out:
# ('Google', 11)
# ('Cybersecurity', 5)
# ('Professional', 34)
# ('Certificate', 34)
# ('Preparing', 7)
# ('for', 7)
# ('Cloud', 15)
# ('Certification:', 7)
# ('Architect', 2)
# ('Security', 1)
# ('Engineer', 6)
# ('Network', 2)
# ('DevOps', 3)
# ('Machine', 1)
# ('Learning', 1)
# ('IT', 4)
# ('Automation', 1)
# ('with', 1)
# ('Python', 1)
# ('Developer', 9)
# ('AWS', 2)
# ('Solutions', 1)
# ('', 5)
# ('IBM', 10)
# ('Applied', 1)
# ('Engineering', 3)
# ('Meta', 6)
# ('AR', 1)
# ('Akamai', 2)
# ('Customer', 1)
# ('Consulting', 1)
# ('and', 3)
# ('Support', 3)
# ('Palo', 1)
# ('Alto', 1)
# ('Networks', 1)
# ('Full-Stack', 1)
# ('JavaScript', 1)
# ('Back-End', 2)
# ('Development', 1)
# ('Front-End', 2)
# ('Database', 1)
# ('Project', 1)
# ('Manager', 1)
# ('ISC2', 1)
# ('Specialist', 1)
# ('iOS', 1)
# ('Android', 1)
# ('Technology', 2)
# ('Consultant', 2)
# ('SAP', 1)
# ('Software', 2)
# ('Microsoft', 1)
# ('Analyst', 2)
# ('Full', 1)
# ('Stack', 1)
# ('UX', 1)
# ('Design', 1)
